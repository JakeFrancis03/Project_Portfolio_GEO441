# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeFrancis03/Project_Portfolio_GEO441/blob/main/vector-analysis/franci14_week10assignment_vector_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Vector Data / Spatial Analysis**

# %% [markdown]
# Created by [Jacob S. Francis]
#
# [10/29/2025]

# %% [markdown]
# ## **Part 1: John Snow Cholera Maps**
#
# ---

# %% [markdown]
# ### **1a: Water Pump Buffer Map**

# %% [markdown]
# Below is a map of cholera deaths inside a 100m buffer of water pumps in the Soho District of London, 1854.
#
#
# ![pump buffer](https://drive.google.com/uc?export=view&id=1nxr6ghsG_3THmB1KDj_7ElnMVp_1o_v3)

# %% [markdown]
# ### **1b: Cholera Deaths Heatmap**

# %% [markdown]
# Below is a heatmap of cholera deaths in the Soho District of London, 1854.
#
#
# ![heatmap](https://drive.google.com/uc?export=view&id=1K0b_twqp9SSR_GYM-wr8UX3P5jfp417k)

# %% [markdown]
# ## **Part 2: Campgrounds**
#
# ---

# %% [markdown]
# Below is a map of sites suitable for campgrounds on private land near Hugo Lake, MN.
#
# ![private land](https://drive.google.com/uc?export=view&id=1TPXJruLAtOnIopFCZtwgW0BOL3cCdY0p)
