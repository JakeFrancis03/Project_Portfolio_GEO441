# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeFrancis03/Project_Portfolio_GEO441/blob/main/vector-analysis/franci14_week5assignment_queryingvectortables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Querying Vector Data Tables**

# %% [markdown]
# Created by Jacob S. Francis
#
# September 26th, 2025

# %% [markdown]
# ##**Part 1: Oldsters Map**

# %% [markdown]
# Below is a map of high age-index U.S. counties prepared following the Week 5 Assignment Guide.
#
#
#
#
# ![oldsters map](https://drive.google.com/uc?export=view&id=1tPdYgAuQavkPmtvPbzSxyPY2aut9Y1th)

# %% [markdown]
# ##**Part 2: Table Join**

# %% [markdown]
# Below is a screenshot of selected records in a joined table prepared following the Week 5 Assignment Guide.
#
#
#
#
# ![selected records](https://drive.google.com/uc?export=view&id=1rHabgXD9shrOET0frNamAr6Z98clpIlO
# )

# %% [markdown]
# ##**Part 3: Soil Fertility Map**

# %% [markdown]
# Below is a map of soil fertility prepared following the Week 5 Assignment Guide.
#
#
#
#
# ![soil fertility map](https://drive.google.com/uc?export=view&id=17Gcoc2iYxbJp0K-FA9J36JAzbCDe2tH6
# )
