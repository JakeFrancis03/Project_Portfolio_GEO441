# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeFrancis03/Project_Portfolio_GEO441/blob/main/basic-mapping/franci14_week4assignment_datadigitization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Entry & Digitizing**

# %% [markdown]
# Created by Jacob S. Francis
#
# 09/23/2025

# %% [markdown]
# ##**Digitized Township Map**

# %% [markdown]
# Below is a map of May Township prepared following the Week 4 Assignment Guide
#
#
#
#
# ![May Township map](https://drive.google.com/uc?export=view&id=1ph-67zX7IiO4Nk9uAHqdZBwqxzqVtd7L)

# %% [markdown]
# ##**Digitized Subdivision Map**

# %% [markdown]
# Below is a map of the digitized subdivision prepared following the Week 4 Assignment Guide
#
#
#
# ![township map](https://drive.google.com/uc?export=view&id=1b4kvIehNACxtDjKDQWndI05iqIlbSn22)
