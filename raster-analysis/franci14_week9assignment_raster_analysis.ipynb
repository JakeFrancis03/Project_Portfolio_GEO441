# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeFrancis03/Project_Portfolio_GEO441/blob/main/raster-analysis/franci14_week9assignment_raster_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Raster Data Terrain Analysis**

# %% [markdown]
# Created by Jacob Francis
#
# 10/23/2025

# %% [markdown]
# ## **Part 1: Oxford Topography Map**

# %% [markdown]
# Below is a map of Oxford, Ohio's topography, prepared following the [Week 9 Assignment Guide](https://docs.google.com/document/d/1DT_0BKPsmqB9xtcc6IAaj-AdU21O1fyvQZhNYV6DipQ/edit?usp=sharing).
#
#
#
#
#
# ![ox topography](https://drive.google.com/uc?export=view&id=1wPyECRY4KmLbrKJ326crAGjTtBEgInD9)

# %% [markdown]
# ## **Part 2: Oxford Zonal Statistics Map**

# %% [markdown]
# Below is a map of Oxford, Ohio's parcels visualized by average slope, prepared following the [Week 9 Assignment Guide](https://docs.google.com/document/d/1DT_0BKPsmqB9xtcc6IAaj-AdU21O1fyvQZhNYV6DipQ/edit?usp=sharing).
#
#
#
# ![ox zonal stats](https://drive.google.com/uc?export=view&id=1oBBn7pmBGkRn1gJMdAZdgg3q00IZ4qCH)

# %% [markdown]
# ## **Part 3: Reflection**
#
#
#
#
#  &nbsp;&nbsp;&nbsp;&nbsp;When creating both the slope by parcel map and the topography map of Oxford, there are a few key differences and similarities that each map combines. The topography elevation map, for example, provides a very good holistic view of the Oxford area. This map directly displays the areas of low and high elevation across the city. The slope by parcel map also does this in its display, yet it is specific to each parcel in the city, expressing the change in elevation. When combined, these maps actually display a lot of the same elevation data, representing the height of land either by specific parcels of the general area. This map is unique in the way that it includes a vector data layer to display these slope zonal statistics, while the topography model only used raster data and analysis.
