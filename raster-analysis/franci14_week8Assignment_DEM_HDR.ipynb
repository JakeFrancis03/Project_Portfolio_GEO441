# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeFrancis03/Project_Portfolio_GEO441/blob/main/raster-analysis/franci14_week8Assignment_DEM_HDR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Digital Elevation and Hydrology Data**

# %% [markdown]
# Created by Jacob S. Francis
#
# 10/15/2025

# %% [markdown]
# ## **Part 1: Lower St. Croix Watershed Map**

# %% [markdown]
# **Below is a map of the lower St. Croix watershed prepared following the [Week 8 Assignment Guide]**
#
#
# ![st. croix map](https://drive.google.com/uc?export=view&id=1tX8pW8T6uEB6buI0lhjWACLLErD51UNE)

# %% [markdown]
# Population Density, 2020 | [NASA Pop. Density 2020](https://worldview.earthdata.nasa.gov/?l=Reference_Labels_15m(hidden),Reference_Features_15m(hidden),Coastlines_15m,GPW_Population_Density_2020,OCI_PACE_True_Color(hidden),VIIRS_NOAA21_CorrectedReflectance_TrueColor(hidden),VIIRS_NOAA20_CorrectedReflectance_TrueColor(hidden),VIIRS_SNPP_CorrectedReflectance_TrueColor(hidden),MODIS_Aqua_CorrectedReflectance_TrueColor(hidden),MODIS_Terra_CorrectedReflectance_TrueColor&lg=true&t=2025-10-15-T19%3A21%3A30Z)
# ###**Group 3 Ohio Homeownership & Rentiership**
# - Spectral Resolution: Landsat Atmospheric.
# - Spatial Resolution: 0.008333 Decimal Degrees x 0.008333 Decimal Degrees
# - Radiometric Resolution: N/A
# - Temporal Resolution: 5-year Increments.
#
#
#
#
#  &nbsp;&nbsp;&nbsp;&nbsp;I chose the *US Census 2020 Population Density* layer as my Raster choise for a few reasons. Firstly, I chose this data set due to the wide applicability and understanding which can be drawn from it. Considering many urban patterns like homeownership and rentiership are based upon values like population density, using these patterns seen in the population distribution link back to many patterns seen in housing affordability and therefore ownership. Additionally, this layer and data can be used to examine the differences in homeownership and rentiership in Ohio itself when looking at urban and rural areas, examining counties that have higher/lower homeowner rates and comparing it to the population density.
#
#  &nbsp;&nbsp;&nbsp;&nbsp; This data may be difficult to use in great detail for Ohio itself as the spatial resolution is very broad. Though you can zoom into state boundaries and even pst them towards local counties, there will be difficulties in actually using this layer effectivelt at those resolutions.
